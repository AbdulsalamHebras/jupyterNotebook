# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
start=pd.read_excel('20210929_Baseline_Survey_Data.xlsx')
start
# Out:
#        م العام الدراسي       المحافظة       المديرية الحضرية  \
# 0      1     2020/2021  امانة العاصمة  صنعاء القديمة     حضر
# 1      2     2020/2021  امانة العاصمة  صنعاء القديمة     حضر
# 2      3     2020/2021  امانة العاصمة  صنعاء القديمة     حضر
# 3      4     2020/2021  امانة العاصمة  صنعاء القديمة     حضر
# 4      5     2020/2021  امانة العاصمة  صنعاء القديمة     حضر
# ..   ...           ...            ...            ...     ...
# 164  165     2020/2021            عدن       المنصورة     حضر
# 165  166     2020/2021            عدن       المنصورة     حضر
# 166  167     2020/2021            عدن       المنصورة     حضر
# 167  168     2020/2021            عدن       المنصورة     حضر
# 168  169     2020/2021            عدن       المنصورة     حضر
#
#                  إسم المدرسة جنس المدير/ة                    مؤهل المدير  \
# 0        ابن الأمير الصنعاني          ذكر                    جامعي فأعلى
# 1         ابو الحسن الهمداني         أنثى                    جامعي فأعلى
# ...

# %%
start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 21 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   م                                                             169 non-null    int64
#  1   العام الدراسي                                                 169 non-null    object
#  2   المحافظة                                                      169 non-null    object
#  3   المديرية                                                      169 non-null    object
#  4   الحضرية                                                       169 non-null    object
#  5   إسم المدرسة                                                   169 non-null    object
#  6   جنس المدير/ة                                                  169 non-null    object
# ...

# %%
start['المحافظة'].unique()
# Out:
# array(['امانة العاصمة', 'حجة', 'عدن'], dtype=object)

# %%
start[['إجمالي المعلمين الثابتين والمتطوعين والمتعاقدين - الكل','إجمالي كادر المدرسة - الكل']].describe().round(2)
# Out:
#        إجمالي المعلمين الثابتين والمتطوعين والمتعاقدين - الكل  \
# count                                             169.00
# mean                                               51.67
# std                                                26.78
# min                                                 5.00
# 25%                                                31.00
# 50%                                                48.00
# 75%                                                67.00
# max                                               160.00
#
#        إجمالي كادر المدرسة - الكل
# count                      169.00
# mean                        64.34
# std                         32.89
# min                          9.00
# 25%                         39.00
# 50%                         61.00
# 75%                         86.00
# max                        192.00

# %%
start['إسم المدرسة'].value_counts()
# Out:
# مجمع الثورة                2
# الوحدة                     2
# أبو بكر الصديق             2
# التضامن                    2
# ابن الأمير الصنعاني        1
#                           ..
# الشهيد محمد احمد شاجرة     1
# التوحيد                    1
# صهاريج عدن                 1
# غمدان                      1
# علي سالم بن رباع           1
# Name: إسم المدرسة, Length: 165, dtype: int64

# %%
start['إسم المدرسة'].unique()
# Out:
# array(['ابن الأمير الصنعاني', 'ابو الحسن الهمداني', 'الخنساء',
#        'الشهيد اللقية', 'الشيماء', 'جابر بن حيان', 'ذات النطاقين',
#        'نشوان الحميري', 'الطبري', '22_مايو', '27_ابريل', 'آمنة بنت وهب',
#        'ابو بكر الرازي', 'ابوموسى الأشعري', 'التعاون', 'الجيل الجديد',
#        'الحباب بن المنذر', 'الشهيد البرطي', 'الشهيد/ صالح الصايدي',
#        'العروة الوثقى', 'المجد', 'النجاح / ذهبان', 'بئر زاهر',
#        'حسين العلفي', 'شهداء الجوية', 'صناع المجد', 'عمر بن عبدالعزيز',
#        'لقمان الحكيم', 'محسن هارون', 'يحي المتوكل', 'الروضة', 'العروبه',
#        'امهات المؤمنين', 'سعد الأشول', 'المنار للبنات', 'المتنبي',
#        'ابي هريرة', 'زيد بن علي/ جدر', 'الفتح', 'جيل الوحدة', 'الإزدهار',
#        'الإمام الشافعي', 'الفجر الجديد الكولة', 'زياد الفقيه_بيت هديان',
#        'الروض بالقابل', 'مجمع الشهيد عبدالعزيز عبدالغني',
#        'الشهيد/ يحيى مذكور', 'رفيدة الاساسيه', 'بيت عثرب الأساسية',
#        'الشهيد محمد مطهر زيد', 'مجمع عمار بن ياسر', 'كمران',
# ...

# %%
start.isna().sum()
# Out:
# م                                                                 0
# العام الدراسي                                                     0
# المحافظة                                                          0
# المديرية                                                          0
# الحضرية                                                           0
# إسم المدرسة                                                       0
# جنس المدير/ة                                                      0
# مؤهل المدير                                                       0
# نوع مؤهل المدير                                                   0
# تخصص  المدير                                                      0
# مرحلة المدرسة                                                     0
# جنس المدرسة                                                       0
# فترة المدرسة                                                      0
# جنس الفترة الصباحي                                                0
# ...

# %%
start.duplicated().sum()
# Out:
# 0

# %%
start.sample(10)
# Out:
#        م العام الدراسي       المحافظة       المديرية الحضرية  \
# 114  115     2020/2021            عدن           صيرة     حضر
# 126  127     2020/2021  امانة العاصمة        التحرير     حضر
# 127  128     2020/2021  امانة العاصمة        التحرير     حضر
# 64    65     2020/2021  امانة العاصمة           آزال     حضر
# 156  157     2020/2021            عدن       المنصورة     حضر
# 70    71     2020/2021            حجة        المدينة     حضر
# 6      7     2020/2021  امانة العاصمة  صنعاء القديمة     حضر
# 110  111     2020/2021            عدن           صيرة     حضر
# 157  158     2020/2021            عدن       المنصورة     حضر
# 55    56     2020/2021  امانة العاصمة           آزال     حضر
#
#                   إسم المدرسة جنس المدير/ة                    مؤهل المدير  \
# 114             ثانوية باكثير         أنثى                    جامعي فأعلى
# 126        الشهيد/صالح الصماد         أنثى                    جامعي فأعلى
# ...

# %%
start['الحضرية'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
start[start['الحضرية']=='حضر'].groupby('الحضرية').max()['إجمالي المعلمين الثابتين والمتطوعين والمتعاقدين - الكل'].nlargest(10)
# Out:
# الحضرية
# حضر    160
# Name: إجمالي المعلمين الثابتين والمتطوعين والمتعاقدين - الكل, dtype: int64

# %%
start.to_excel('start.xlsx')
